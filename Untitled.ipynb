# %%
import pandas as pd
df = pd.read_csv('/Users/khandekara2/Documents/methylationProject/03_results/Pcg_results.tsv', sep='\t', header=None)
# Out:
# /Users/khandekara2/anaconda3/lib/python3.6/site-packages/numexpr/cpuinfo.py:76: UserWarning: [Errno 2] No such file or directory: 'sysctl': 'sysctl'
#   stacklevel=stacklevel + 1):

# %%
df
# Out:
#                                      0          1     2     3  \
# 0                          tissue_type       gene  nCpG  mCpG
# 1      Breast_Luminal_Epithelial_Cells     CCDC24    26     8
# 2      Breast_Luminal_Epithelial_Cells    C1orf50    40     7
# 3      Breast_Luminal_Epithelial_Cells     PPFIA4    61    44
# 4      Breast_Luminal_Epithelial_Cells       CAP1     9     9
# 5      Breast_Luminal_Epithelial_Cells     MMACHC    17    13
# 6      Breast_Luminal_Epithelial_Cells      PRDX1     4     4
# 7      Breast_Luminal_Epithelial_Cells     CCDC23     0     0
# 8      Breast_Luminal_Epithelial_Cells     SLC6A9    94    75
# 9      Breast_Luminal_Epithelial_Cells      ERMAP    12    12
# 10     Breast_Luminal_Epithelial_Cells       MYOG    27    27
# 11     Breast_Luminal_Epithelial_Cells     AKR1A1    17    10
# 12     Breast_Luminal_Epithelial_Cells     ADORA1    45    45
# 13     Breast_Luminal_Epithelial_Cells     ZNF691    28    28
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
p = np.array(df.iloc[:, 4])
n,bins,edges = plt.hist(p, bins=20, weights=np.zeros_like(p) + 1. / p.size)
plt.xticks([0.05, 0.95])
plt.ylabel('Frequency', fontsize=14)
plt.xlabel(r'$P_{CG}$', fontsize=18)
plt.savefig('Breast_P_CG.png')

# %%
zeroes = df[df.iloc[:, 2] == 0]

# %%
print (zeroes.shape[0])
# Out:
# 0

# %%
print (df.shape[0])
# Out:
# 12305
