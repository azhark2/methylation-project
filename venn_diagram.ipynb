# %%
from matplotlib import pyplot as plt
from matplotlib_venn import venn2, venn2_circles
s = (2, 3, 1)
v = venn2(subsets=s, set_labels=('WGBS Samples', 'Somatic Mutation Samples'))
v.get_label_by_id('10').set_text('8')
v.get_label_by_id('01').set_text('346')
v.get_label_by_id('11').set_text('34')

v.get_patch_by_id('10').set_color('b')
v.get_patch_by_id('01').set_color('y')
v.get_patch_by_id('11').set_color('c')

v.get_patch_by_id('10').set_alpha(0.4)
v.get_patch_by_id('01').set_alpha(1.0)
v.get_patch_by_id('11').set_alpha(0.7)
# c = venn2_circles(subsets=s, linestyle='solid')
# c[0].set_ls('dashed')  # Line style
# c[0].set_lw(2.0)       # Line width
for t in v.subset_labels: t.set_fontsize(20)
plt.title('PBCA', fontsize=15)
plt.savefig('PBCA_venn.png')
plt.show()

# %%
v = venn2(subsets=s, set_labels=('WGBS Samples', 'Somatic Mutation Samples'))
v.get_label_by_id('10').set_text('4')
v.get_label_by_id('01').set_text('78')
v.get_label_by_id('11').set_text('22')

v.get_patch_by_id('10').set_color('b')
v.get_patch_by_id('01').set_color('y')
v.get_patch_by_id('11').set_color('c')

v.get_patch_by_id('10').set_alpha(0.4)
v.get_patch_by_id('01').set_alpha(1.0)
v.get_patch_by_id('11').set_alpha(0.7)

for t in v.set_labels: t.set_fontsize(12)
for t in v.subset_labels: t.set_fontsize(20)
# c = venn2_circles(subsets=s, linestyle='solid')
# c[0].set_ls('dashed')  # Line style
# c[0].set_lw(2.0)       # Line width
plt.title("MALY", fontsize=15)
plt.savefig('MALY_venn.png')
plt.show()

# %%
v = venn2(subsets=s, set_labels=('WGBS Samples', 'Somatic Mutation Samples'))
v.get_label_by_id('10').set_text('3')
v.get_label_by_id('01').set_text('222')
v.get_label_by_id('11').set_text('2')

v.get_patch_by_id('10').set_color('b')
v.get_patch_by_id('01').set_color('y')
v.get_patch_by_id('11').set_color('c')

v.get_patch_by_id('10').set_alpha(0.4)
v.get_patch_by_id('01').set_alpha(1.0)
v.get_patch_by_id('11').set_alpha(0.7)
# c = venn2_circles(subsets=s, linestyle='solid')
# c[0].set_ls('dashed')  # Line style
# c[0].set_lw(2.0)       # Line width
for t in v.subset_labels: t.set_fontsize(20)
plt.title("CLLE", fontsize=15)
plt.savefig('CLLE_venn.png')
plt.show()
